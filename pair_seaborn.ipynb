# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import re
import numpy as np

# %%
"""
1 - Usando la librería seaborn, cread una gráfica que nos muestre el número de personas que han hecho una solicitud de ticket en cada año. Hacedlo solo para los del tipo "Problema".

"""
# Out:
# '\n1 - Usando la librería seaborn, cread una gráfica que nos muestre el número de personas que han hecho una solicitud de ticket en cada año. Hacedlo solo para los del tipo "Problema".\n\n'

# %%
df_puestos = pd.read_csv("data/union_años.csv")
df_puestos.head()
# Out:
#    Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 0           0  GDDENR-5042564453  2016-07-13       1735.0        4.0
# 1           1  GDDENR-8042508060  2016-05-18       1566.0       10.0
# 2           2  GDDESR-1342539995  2016-06-18        569.0       29.0
# 3           3  GDDTSR-5942488006  2016-04-28        320.0       40.0
# 4           4  GDLEER-0042524120  2016-06-03       1842.0       31.0
#
#        categoría       tipo           severidad        prioridad  \
# 0  Acceso&%Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 1  Acceso&%Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 2        Sistema   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 3        Sistema  Solicitud  0 - Sin Clasificar  0 - Sin Asignar
# 4       Software   Problema          2 - Normal  0 - Sin Asignar
#
#    días_resolución  satisfacción
# 0              0.0           5.0
# 1              0.0           5.0
# 2              3.0           5.0
# 3              9.0           5.0
# 4              0.0           5.0

# %%
patron1 = "Problema"
condicion =["Problema"]

df_problema = df_puestos[df_puestos['tipo'].isin(condicion)]

# %%
df_problema
# Out:
#        Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 0               0  GDDENR-5042564453  2016-07-13       1735.0        4.0
# 1               1  GDDENR-8042508060  2016-05-18       1566.0       10.0
# 2               2  GDDESR-1342539995  2016-06-18        569.0       29.0
# 4               4  GDLEER-0042524120  2016-06-03       1842.0       31.0
# 5               5  GDLEER-0142608095  2016-08-26         59.0       20.0
# ...           ...                ...         ...          ...        ...
# 97456       29046  TWRESR-7244098112  2020-09-24       1891.0       41.0
# 97457       29047  TWRESR-8044058342  2020-08-15        394.0       33.0
# 97458       29048  TWRESR-8443962836  2020-05-11        403.0        8.0
# 97459       29049  TWRESR-9544015158  2020-07-03        935.0       31.0
# 97460       29050  TWREST-6744042617  2020-07-30        681.0       36.0
#
#            categoría      tipo           severidad        prioridad  \
# 0      Acceso&%Login  Problema  0 - Sin Clasificar  0 - Sin Asignar
# 1      Acceso&%Login  Problema  0 - Sin Clasificar  0 - Sin Asignar
# 2            Sistema  Problema  0 - Sin Clasificar  0 - Sin Asignar
# 4           Software  Problema          2 - Normal  0 - Sin Asignar
# 5           Software  Problema          2 - Normal  0 - Sin Asignar
# ...              ...       ...                 ...              ...
# 97456        Sistema  Problema           3 - Mayor         1 - Baja
# 97457        Sistema  Problema           3 - Mayor         1 - Baja
# 97458        Sistema  Problema           1 - Menor         1 - Baja
# 97459        Sistema  Problema           3 - Mayor         1 - Baja
# 97460        Sistema  Problema           3 - Mayor         1 - Baja
#
#        días_resolución  satisfacción
# 0                  0.0           5.0
# 1                  0.0           5.0
# 2                  3.0           5.0
# 4                  0.0           5.0
# 5                  1.0           1.0
# ...                ...           ...
# 97456              2.0           5.0
# 97457             10.0           4.0
# 97458              4.0           4.0
# 97459              5.0           5.0
# 97460              7.0           5.0
#
# [24278 rows x 11 columns]

# %%
plt.figure(figsize =(8,4))

fig = sns.lineplot(x='fecha' , y='id_ticket' , data= df_problema , ci=None)

fig.set(xlabel='Tickets emitidos', ylabel='Años')

fig.set_title('Gráfica lineal problemas por ticket')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_555/508388754.py in <module>
#       1 plt.figure(figsize =(8,4))
#       2
# ----> 3 fig = sns.lineplot(x='fecha' , y='id_ticket' , data= df_problema , ci=None)
#       4
#       5 fig.set(xlabel='Tickets emitidos', ylabel='Años')
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     708     p._attach(ax)
#     709
# --> 710     p.plot(ax, kwargs)
#     711     return ax
#     712
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/relational.py in plot(self, ax, kws)
#     555
#     556         # Finalize the axes details
# --> 557         self._add_axis_labels(ax)
#     558         if self.legend:
#     559             self.add_legend_data(ax)
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/_core.py in _add_axis_labels(self, ax, default_x, default_y)
#    1195             ax.set_xlabel(self.variables.get("x", default_x), visible=x_visible)
#    1196         if not ax.get_ylabel():
# -> 1197             y_visible = any(t.get_visible() for t in ax.get_yticklabels())
#    1198             ax.set_ylabel(self.variables.get("y", default_y), visible=y_visible)
#    1199
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1230         if minor:
#    1231             return self.get_minorticklabels()
# -> 1232         return self.get_majorticklabels()
#    1233
#    1234     def get_majorticklines(self):
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1182     def get_majorticklabels(self):
#    1183         """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1184         ticks = self.get_major_ticks()
#    1185         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1186         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1357         while len(self.majorTicks) < numticks:
#    1358             # Update the new tick label properties from the old.
# -> 1359             tick = self._get_tick(major=True)
#    1360             self.majorTicks.append(tick)
#    1361             self._copy_tick_props(self.majorTicks[0], tick)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2330         else:
#    2331             tick_kw = self._minor_tick_kw
# -> 2332         return YTick(self.axes, 0, major=major, **tick_kw)
#    2333
#    2334     def set_label_position(self, position):
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     485
#     486     def __init__(self, *args, **kwargs):
# --> 487         super().__init__(*args, **kwargs)
#     488         # x in axes coords, y in data coords
#     489         self.tick1line.set(
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     169         self.gridline.get_path()._interpolation_steps = \
#     170             GRIDLINE_INTERPOLATION_STEPS
# --> 171         self.label1 = mtext.Text(
#     172             np.nan, np.nan,
#     173             fontsize=labelsize, color=labelcolor, visible=label1On)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/text.py in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, transform_rotates_text, **kwargs)
#     155         self.set_color(
#     156             color if color is not None else mpl.rcParams["text.color"])
# --> 157         self.set_fontproperties(fontproperties)
#     158         self.set_usetex(usetex)
#     159         self.set_wrap(wrap)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/text.py in set_fontproperties(self, fp)
#    1249             absolute path to a font file.
#    1250         """
# -> 1251         self._fontproperties = FontProperties._from_any(fp).copy()
#    1252         self.stale = True
#    1253
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7f1615e413a0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in _fetch_figure_metadata(fig)
#     229     if _is_transparent(fig.get_facecolor()):
#     230         # the background is transparent
# --> 231         ticksLight = _is_light([label.get_color()
#     232                                 for axes in fig.axes
#     233                                 for axis in (axes.xaxis, axes.yaxis)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in <listcomp>(.0)
#     232                                 for axes in fig.axes
#     233                                 for axis in (axes.xaxis, axes.yaxis)
# --> 234                                 for label in axis.get_ticklabels()])
#     235         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     236             # there are one or more tick labels, all with the same lightness
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1230         if minor:
#    1231             return self.get_minorticklabels()
# -> 1232         return self.get_majorticklabels()
#    1233
#    1234     def get_majorticklines(self):
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1182     def get_majorticklabels(self):
#    1183         """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1184         ticks = self.get_major_ticks()
#    1185         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1186         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1357         while len(self.majorTicks) < numticks:
#    1358             # Update the new tick label properties from the old.
# -> 1359             tick = self._get_tick(major=True)
#    1360             self.majorTicks.append(tick)
#    1361             self._copy_tick_props(self.majorTicks[0], tick)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2330         else:
#    2331             tick_kw = self._minor_tick_kw
# -> 2332         return YTick(self.axes, 0, major=major, **tick_kw)
#    2333
#    2334     def set_label_position(self, position):
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     485
#     486     def __init__(self, *args, **kwargs):
# --> 487         super().__init__(*args, **kwargs)
#     488         # x in axes coords, y in data coords
#     489         self.tick1line.set(
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     172             np.nan, np.nan,
#     173             fontsize=labelsize, color=labelcolor, visible=label1On)
# --> 174         self.label2 = mtext.Text(
#     175             np.nan, np.nan,
#     176             fontsize=labelsize, color=labelcolor, visible=label2On)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/text.py in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, transform_rotates_text, **kwargs)
#     153         self._text = ''
#     154         self.set_text(text)
# --> 155         self.set_color(
#     156             color if color is not None else mpl.rcParams["text.color"])
#     157         self.set_fontproperties(fontproperties)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/text.py in set_color(self, color)
#     938         # out at draw time for simplicity.
#     939         if not cbook._str_equal(color, "auto"):
# --> 940             mpl.colors._check_color_like(color=color)
#     941         # Make sure it is hashable, or get_prop_tup will fail.
#     942         try:
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/colors.py in _check_color_like(**kwargs)
#     153     """
#     154     for k, v in kwargs.items():
# --> 155         if not is_color_like(v):
#     156             raise ValueError(f"{v!r} is not a valid value for {k}")
#     157
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/colors.py in is_color_like(c)
#     141         return True
#     142     try:
# --> 143         to_rgba(c)
#     144     except ValueError:
#     145         return False
#
# KeyboardInterrupt:

# %%
"""
2 - La gráfica anterior nos ha mostrado una tendencia ascendente en el número de solicitudes a lo largo de los años, lo que preocupa a la empresa, por lo que quieren seguir analizando los datos para ver 
si son capaces de identificar los problemas subyacentes a estas solicitudes. Para esto, quieren saber si hay diferencias a lo largo del año. En concreto nos piden que hagamos un subplot con seaborn donde:


- En la primera gráfica tengamos la gráfica que creamos en el ejercicio anterior
- En la segunda gráfica tengamos la comparación por años y sementres para el número de tikects de tipo "Problema".

"""

# %%
patron_semestre = '.+-0[1-6]-.+'
df_problema['semestre'] = np.where(df_problema["fecha"].str.contains(patron_semestre, regex=True), '1er semestre', '2º semestre')
df_problema.head()
# Out:
# /tmp/ipykernel_555/2277253024.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_problema['semestre'] = np.where(df_problema["fecha"].str.contains(patron_semestre, regex=True), '1er semestre', '2º semestre')
#    Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 0           0  GDDENR-5042564453  2016-07-13       1735.0        4.0
# 1           1  GDDENR-8042508060  2016-05-18       1566.0       10.0
# 2           2  GDDESR-1342539995  2016-06-18        569.0       29.0
# 4           4  GDLEER-0042524120  2016-06-03       1842.0       31.0
# 5           5  GDLEER-0142608095  2016-08-26         59.0       20.0
#
#        categoría      tipo           severidad        prioridad  \
# 0  Acceso&%Login  Problema  0 - Sin Clasificar  0 - Sin Asignar
# 1  Acceso&%Login  Problema  0 - Sin Clasificar  0 - Sin Asignar
# 2        Sistema  Problema  0 - Sin Clasificar  0 - Sin Asignar
# 4       Software  Problema          2 - Normal  0 - Sin Asignar
# 5       Software  Problema          2 - Normal  0 - Sin Asignar
#
#    días_resolución  satisfacción      semestre
# 0              0.0           5.0   2º semestre
# 1              0.0           5.0  1er semestre
# 2              3.0           5.0  1er semestre
# 4              0.0           5.0  1er semestre
# 5              1.0           1.0   2º semestre

# %%
fig, axes= plt.subplots(1,2,figsize =(8,4))

sns.lineplot(x='fecha' , y='id_ticket' , data= df_problema , ci=None, ax = axes[0])
sns.countplot(x='fecha' , y='id_ticket' , data= df_problema , hue= "semestre", ci=None, ax = axes[1])


fig.set_title('Gráfica lineal problemas por ticket')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_555/992665126.py in <module>
#       1 fig, axes= plt.subplots(1,2,figsize =(8,4))
#       2
# ----> 3 sns.lineplot(x='fecha' , y='id_ticket' , data= df_problema , ci=None, ax = axes[0])
#       4 sns.countplot(x='fecha' , y='id_ticket' , data= df_problema , hue= "semestre", ci=None, ax = axes[1])
#       5
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     708     p._attach(ax)
#     709
# --> 710     p.plot(ax, kwargs)
#     711     return ax
#     712
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/relational.py in plot(self, ax, kws)
#     555
#     556         # Finalize the axes details
# --> 557         self._add_axis_labels(ax)
#     558         if self.legend:
#     559             self.add_legend_data(ax)
#
# ~/anaconda3/lib/python3.9/site-packages/seaborn/_core.py in _add_axis_labels(self, ax, default_x, default_y)
#    1195             ax.set_xlabel(self.variables.get("x", default_x), visible=x_visible)
#    1196         if not ax.get_ylabel():
# -> 1197             y_visible = any(t.get_visible() for t in ax.get_yticklabels())
#    1198             ax.set_ylabel(self.variables.get("y", default_y), visible=y_visible)
#    1199
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1230         if minor:
#    1231             return self.get_minorticklabels()
# -> 1232         return self.get_majorticklabels()
#    1233
#    1234     def get_majorticklines(self):
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1182     def get_majorticklabels(self):
#    1183         """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1184         ticks = self.get_major_ticks()
#    1185         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1186         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1357         while len(self.majorTicks) < numticks:
#    1358             # Update the new tick label properties from the old.
# -> 1359             tick = self._get_tick(major=True)
#    1360             self.majorTicks.append(tick)
#    1361             self._copy_tick_props(self.majorTicks[0], tick)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2330         else:
#    2331             tick_kw = self._minor_tick_kw
# -> 2332         return YTick(self.axes, 0, major=major, **tick_kw)
#    2333
#    2334     def set_label_position(self, position):
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     485
#     486     def __init__(self, *args, **kwargs):
# --> 487         super().__init__(*args, **kwargs)
#     488         # x in axes coords, y in data coords
#     489         self.tick1line.set(
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     161             markeredgecolor=color, markersize=size, markeredgewidth=width,
#     162         )
# --> 163         self.gridline = mlines.Line2D(
#     164             [], [],
#     165             color=grid_color, alpha=grid_alpha, visible=gridOn,
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     369         self.set_linewidth(linewidth)
#     370         self.set_linestyle(linestyle)
# --> 371         self.set_drawstyle(drawstyle)
#     372
#     373         self._color = None
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/lines.py in set_drawstyle(self, drawstyle)
#    1086         _api.check_in_list(self.drawStyles, drawstyle=drawstyle)
#    1087         if self._drawstyle != drawstyle:
# -> 1088             self.stale = True
#    1089             # invalidate to trigger a recache of the path
#    1090             self._invalidx = True
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in stale(self, val)
#     239         return self._stale
#     240
# --> 241     @stale.setter
#     242     def stale(self, val):
#     243         self._stale = val
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7f1615e413a0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in _fetch_figure_metadata(fig)
#     229     if _is_transparent(fig.get_facecolor()):
#     230         # the background is transparent
# --> 231         ticksLight = _is_light([label.get_color()
#     232                                 for axes in fig.axes
#     233                                 for axis in (axes.xaxis, axes.yaxis)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in <listcomp>(.0)
#     232                                 for axes in fig.axes
#     233                                 for axis in (axes.xaxis, axes.yaxis)
# --> 234                                 for label in axis.get_ticklabels()])
#     235         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     236             # there are one or more tick labels, all with the same lightness
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1230         if minor:
#    1231             return self.get_minorticklabels()
# -> 1232         return self.get_majorticklabels()
#    1233
#    1234     def get_majorticklines(self):
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1182     def get_majorticklabels(self):
#    1183         """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1184         ticks = self.get_major_ticks()
#    1185         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1186         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1357         while len(self.majorTicks) < numticks:
#    1358             # Update the new tick label properties from the old.
# -> 1359             tick = self._get_tick(major=True)
#    1360             self.majorTicks.append(tick)
#    1361             self._copy_tick_props(self.majorTicks[0], tick)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2330         else:
#    2331             tick_kw = self._minor_tick_kw
# -> 2332         return YTick(self.axes, 0, major=major, **tick_kw)
#    2333
#    2334     def set_label_position(self, position):
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     485
#     486     def __init__(self, *args, **kwargs):
# --> 487         super().__init__(*args, **kwargs)
#     488         # x in axes coords, y in data coords
#     489         self.tick1line.set(
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     172             np.nan, np.nan,
#     173             fontsize=labelsize, color=labelcolor, visible=label1On)
# --> 174         self.label2 = mtext.Text(
#     175             np.nan, np.nan,
#     176             fontsize=labelsize, color=labelcolor, visible=label2On)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/text.py in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, transform_rotates_text, **kwargs)
#     153         self._text = ''
#     154         self.set_text(text)
# --> 155         self.set_color(
#     156             color if color is not None else mpl.rcParams["text.color"])
#     157         self.set_fontproperties(fontproperties)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/text.py in set_color(self, color)
#     938         # out at draw time for simplicity.
#     939         if not cbook._str_equal(color, "auto"):
# --> 940             mpl.colors._check_color_like(color=color)
#     941         # Make sure it is hashable, or get_prop_tup will fail.
#     942         try:
#
# KeyboardInterrupt:

# %%
"""
3 - La empresa se siente algo aliviada al ver que no hay diferencias entre semestres, pero seguimos sin identificar porque cada año tenemos más solicitudes.
Nuestras jefas quieren saber ahora, que prioridad tienen los tickets que tenemos en el conjunto de datos. Por eso nos piden que volvamos a hacer un subplot:

- En la primera gráfica deberíamos tener la gráfica creada en el ejercicio 1
- En la segunda gráfica deberíamos incluir el número de tickets por año en función de la prioridad que tienen.

"""

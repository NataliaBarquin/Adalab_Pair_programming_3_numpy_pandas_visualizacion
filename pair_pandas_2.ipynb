# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# Ejercicio 1

# %%
documento_csv = pd.read_csv('data/quejas.csv', sep = ';',  encoding = 'latin-1')

# %%
documento_csv
# Out:
#             tipo                   estado canal_entrada        fecha_entrada  \
# 0          Queja  Recepcionada por Unidad      INTERNET  2022-01-28 00:00:00
# 1          Queja  Recepcionada por Unidad      INTERNET  2022-03-28 00:00:00
# 2          Queja  Recepcionada por Unidad      INTERNET  2022-03-23 00:00:00
# 3          Queja  Recepcionada por Unidad      INTERNET  2022-01-24 00:00:00
# 4          Queja  Recepcionada por Unidad      INTERNET  2022-03-29 00:00:00
# ...          ...                      ...           ...                  ...
# 4494  Sugerencia                Cancelada      INTERNET  2022-01-02 00:00:00
# 4495  Sugerencia       Rechazada por SGAC      INTERNET  2022-03-08 00:00:00
# 4496       Queja       Rechazada por SGAC      INTERNET  2022-01-24 00:00:00
# 4497       Queja       Rechazada por SGAC      INTERNET  2022-01-21 00:00:00
# 4498       Queja       Rechazada por SGAC      INTERNET  2022-01-21 00:00:00
#
# ...

# %%
df_sugerencias = documento_csv.loc[documento_csv['tipo'] == 'Sugerencia']

# %%
df_sugerencias
# Out:
#             tipo                         estado canal_entrada  \
# 5     Sugerencia        Contestada al Ciudadano      INTERNET
# 7     Sugerencia        Contestada al Ciudadano      INTERNET
# 34    Sugerencia        Contestada al Ciudadano      INTERNET
# 37    Sugerencia        Contestada al Ciudadano      INTERNET
# 40    Sugerencia        Recepcionada por Unidad      INTERNET
# ...          ...                            ...           ...
# 4460  Sugerencia        Contestada al Ciudadano      INTERNET
# 4479  Sugerencia  Enviada a Otra Administración      INTERNET
# 4480  Sugerencia  Enviada a Otra Administración      INTERNET
# 4494  Sugerencia                      Cancelada      INTERNET
# 4495  Sugerencia             Rechazada por SGAC      INTERNET
#
#             fecha_entrada   fecha_contestacion  \
# 5     2022-03-08 00:00:00  2022-03-14 00:00:00
# 7     2022-01-24 00:00:00  2022-02-01 00:00:00
# 34    2022-03-28 00:00:00  2022-03-31 00:00:00
# ...

# %%
df_queja_presencial = documento_csv[(documento_csv.tipo == 'Queja') & (documento_csv.canal_entrada == 'PRESENCIAL')]
df_queja_presencial
# Out:
#        tipo                         estado canal_entrada        fecha_entrada  \
# 45    Queja                      Cancelada    PRESENCIAL  2022-01-31 00:00:00
# 197   Queja        Contestada al Ciudadano    PRESENCIAL  2022-02-17 00:00:00
# 420   Queja        Contestada al Ciudadano    PRESENCIAL  2022-02-14 00:00:00
# 421   Queja        Contestada al Ciudadano    PRESENCIAL  2022-02-11 00:00:00
# 422   Queja        Contestada al Ciudadano    PRESENCIAL  2022-02-14 00:00:00
# ...     ...                            ...           ...                  ...
# 4323  Queja        Recepcionada por Unidad    PRESENCIAL  2022-01-17 00:00:00
# 4336  Queja        Recepcionada por Unidad    PRESENCIAL  2022-02-23 00:00:00
# 4412  Queja        Contestada al Ciudadano    PRESENCIAL  2022-02-07 00:00:00
# 4455  Queja        Contestada al Ciudadano    PRESENCIAL  2022-03-10 00:00:00
# 4465  Queja  Enviada a Otra Administración    PRESENCIAL  2022-01-17 00:00:00
#
# ...

# %%
df_queja_presencial.iloc[:,3:5]
# Out:
#             fecha_entrada   fecha_contestacion
# 45    2022-01-31 00:00:00                  NaN
# 197   2022-02-17 00:00:00  2022-02-23 00:00:00
# 420   2022-02-14 00:00:00  2022-02-15 00:00:00
# 421   2022-02-11 00:00:00  2022-02-11 00:00:00
# 422   2022-02-14 00:00:00  2022-02-15 00:00:00
# ...                   ...                  ...
# 4323  2022-01-17 00:00:00                  NaN
# 4336  2022-02-23 00:00:00                  NaN
# 4412  2022-02-07 00:00:00  2022-02-10 00:00:00
# 4455  2022-03-10 00:00:00  2022-03-18 00:00:00
# 4465  2022-01-17 00:00:00                  NaN
#
# [726 rows x 2 columns]

# %% [markdown]
# Ejercicio 2

# %%
df_clipboard = pd.read_clipboard()
df_clipboard
# Out:
#                                         Marzo  Abril   Mayo  Junio  ​​Julio   \
#                         Enero  Febrero
# Temperatura media (°C)  4.8    6          9.2   12.2   16.7   22.8       26
# Temperatura min. (°C)   0.9    1.4        3.8    6.4   10.3   15.7     18.8
# Temperatura máx. (°C)   9.5    11.4        15   17.9   22.6     29     32.4
# Precipitación (mm)      41     34          40     47     39     16        6
# Humedad(%)              77%    69%        60%    57%    48%    35%      28%
# Días lluviosos (días)   5      4            4      6      5      3        1
# Horas de sol (horas)    5.7    6.8        8.1    9.4   11.5   13.0     13.1
#
#                                         Agosto  Septiembre  Octubre   \
#                         Enero  Febrero
# Temperatura media (°C)  4.8    6          25.6        20.9     15.1
# Temperatura min. (°C)   0.9    1.4        18.5        14.8     10.2
# Temperatura máx. (°C)   9.5    11.4       31.9        26.8     20.3
# ...

# %%
df_clipboard.reset_index(inplace = True)

# %%
df_clipboard
# Out:
#                            Enero  Febrero  Marzo  Abril   Mayo  Junio   \
# 0  Temperatura media (°C)    4.8        6    9.2   12.2   16.7   22.8
# 1   Temperatura min. (°C)    0.9      1.4    3.8    6.4   10.3   15.7
# 2   Temperatura máx. (°C)    9.5     11.4     15   17.9   22.6     29
# 3      Precipitación (mm)     41       34     40     47     39     16
# 4              Humedad(%)    77%      69%    60%    57%    48%    35%
# 5   Días lluviosos (días)      5        4      4      6      5      3
# 6    Horas de sol (horas)    5.7      6.8    8.1    9.4   11.5   13.0
#
#   ​​Julio  Agosto  Septiembre  Octubre  Noviembre  Diciembre
# 0      26    25.6        20.9     15.1        8.6        5.5
# 1    18.8    18.5        14.8     10.2        4.7        1.8
# 2    32.4    31.9        26.8     20.3       13.2       10.1
# 3       6       8          22       61         55         46
# 4     28%     30%         41%      60%        72%        77%
# ...

# %%
df_clipboard.iloc[1:3, 2:3]
# Out:
#   Febrero
# 1     1.4
# 2    11.4

# %%
df_clipboard.loc['6	Horas de sol (horas)', 'Julio	']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/adalabenv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/envs/adalabenv/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/adalabenv/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Julio\t'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# No es posible conseguir la información con LOC porque no detecta correctamente el nombre de las filas y columnas. Lo probamos con ILOC:

# %%
df_clipboard.iloc[6:7, 7:8]
# Out:
#   ​​Julio
# 6    13.1

# %%
df_clipboard.iloc[3:5, 9:10]
# Out:
#   Septiembre
# 3         22
# 4        41%

# %%
df_clipboard['Años'] = '1991-2021'

# %%
df_clipboard
# Out:
#                            Enero  Febrero  Marzo  Abril   Mayo  Junio   \
# 0  Temperatura media (°C)    4.8        6    9.2   12.2   16.7   22.8
# 1   Temperatura min. (°C)    0.9      1.4    3.8    6.4   10.3   15.7
# 2   Temperatura máx. (°C)    9.5     11.4     15   17.9   22.6     29
# 3      Precipitación (mm)     41       34     40     47     39     16
# 4              Humedad(%)    77%      69%    60%    57%    48%    35%
# 5   Días lluviosos (días)      5        4      4      6      5      3
# 6    Horas de sol (horas)    5.7      6.8    8.1    9.4   11.5   13.0
#
#   ​​Julio  Agosto  Septiembre  Octubre  Noviembre  Diciembre       Años
# 0      26    25.6        20.9     15.1        8.6        5.5  1991-2021
# 1    18.8    18.5        14.8     10.2        4.7        1.8  1991-2021
# 2    32.4    31.9        26.8     20.3       13.2       10.1  1991-2021
# 3       6       8          22       61         55         46  1991-2021
# ...

# %%
df_clipboard.to_csv('data/clipboard_csv.csv')

# %%
df_clipboard.to_excel('data/clipboard_excel.xlsx')

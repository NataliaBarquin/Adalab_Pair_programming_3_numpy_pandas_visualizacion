# %%
import pandas as pd

# %%
agentes = pd.read_csv('data/Agentes.csv')
agentes.head()
# Out:
#    ID Agente               Nombre                              email  \
# 0          1          Mata Lucero          lucero.mata@tractchun.com
# 1          2         JesusGrajeda        jesus.grajeda@tractchun.com
# 2          3          Elena Velez          elena.velez@tractchun.com
# 3          4      Barraza Alberto      alberto.barraza@tractchun.com
# 4          5  Willyberto Gonzales  willyberto.gonzales@tractchun.com
#
#   Fecha de Nacimiento
# 0           1989/4/28
# 1            1979/1/1
# 2            1993/6/6
# 3          1978/10/20
# 4           1973/5/11

# %%
puestos = pd.read_csv('data/puestos.csv')
puestos.head()
# Out:
#    Unnamed: 0 ID Puesto                            Puesto Departamento  \
# 0           0  10-23200           Ingeniero de Materiales   MATERIALES
# 1           1  10-24111            Operador de Producción   MATERIALES
# 2           2  10-25120               Auxiliar de compras   MATERIALES
# 3           3  10-25130                         Comprador   MATERIALES
# 4           4  10-32050  Supervisor General de Materiales   MATERIALES
#
#       Tipo Puesto
# 0       Operativo
# 1       Operativo
# 2  Administrativo
# 3  Administrativo
# 4   Mandos Medios

# %%
empleados = pd.read_csv('data/Empleados.csv')
empleados.head()
# Out:
#   Turno  ID Empleado Apellido     Nombre ID Puesto  \
# 0     A            6    VILLA      JESUS  50-32200
# 1   NaN           10   MENDEZ    RICARDO  15-24100
# 2   NaN           21  HEREDIA  GUADALUPE  90-14000
# 3   NaN           27    DURAN    DESSENS  15-24100
# 4   NaN           29   LAGUNA   FEDERICO  80-24100
#
#                              Email
# 0        jesus.villa@tractchun.com
# 1     ricardo.mendez@tractchun.com
# 2  guadalupe.heredia@tractchun.com
# 3      dessens.duran@tractchun.com
# 4    federico.laguna@tractchun.com

# %%
excel_2016 = pd.read_excel('data/2016.xlsx')
excel_2016.head(2)
# Out:
#            ID Ticket      Fecha  ID Empleado  ID Agente      Categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
#
#        Tipo           Severidad        Prioridad  Días Resolución  \
# 0  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
#
#    Satisfacción               Web  Índice
# 0           5.0  www.tractchun.es      1.0
# 1           5.0  www.tractchun.es      1.0

# %%
excel_2017 = pd.read_excel('data/2017.xlsx')
excel_2017.head(2)
# Out:
#            ID Ticket      Fecha  ID Empleado  ID Agente Categoría      Tipo  \
# 0  GDDEER-8142900901 2017-06-14         1200         29  Software  Problema
# 1  GDDEST-7342745152 2017-01-10         1855         31   Sistema  Problema
#
#             Severidad        Prioridad  Días Resolución  Satisfacción
# 0  0 - Sin Clasificar  0 - Sin Asignar                1             5
# 1  0 - Sin Clasificar  0 - Sin Asignar                3             5

# %%
excel_2017.to_csv("data/2017.csv")

# %%
excel_2018 = pd.read_excel('data/2018.xlsx')
excel_2018.head(2)
# Out:
#            ID Ticket      Fecha  ID Empleado  ID Agente      Categoría  \
# 0  GDDEER-9743106195 2018-01-06          759         21       Hardware
# 1  GDDENR-9043229214 2018-05-09          521          2  Acceso-&Login
#
#        Tipo           Severidad        Prioridad  Días Resolución  \
# 0  Problema  0 - Sin Clasificar  0 - Sin Asignar                7
# 1  Problema  0 - Sin Clasificar  0 - Sin Asignar                0
#
#    Satisfacción
# 0             5
# 1             5

# %%
excel_2018.to_csv("data/2018.csv")

# %%
excel_2019 = pd.read_excel('data/2019.xlsx')
excel_2019.head(2)
# Out:
#            ID Ticket      Fecha  ID Empleado  ID Agente Categoría      Tipo  \
# 0  GDDEER-5743562837 2019-04-07         1833         48  Hardware  Problema
# 1  GDDEER-6043685286 2019-08-08          528         32  Hardware  Problema
#
#             Severidad        Prioridad  Días Resolución  Satisfacción
# 0  0 - Sin Clasificar  0 - Sin Asignar                7             5
# 1  0 - Sin Clasificar  0 - Sin Asignar               10             5

# %%
excel_2019.to_csv("data/2019.csv")

# %%
excel_2020 = pd.read_excel('data/2020.xlsx')
excel_2020.head(2)
# Out:
#            ID Ticket      Fecha      Tipo     Categoría  ID Empleado  \
# 0  GDDENR-6044135832 2020-10-31  Problema  Acceso/Login          773
# 1  GDDESR-1444031730 2020-07-19  Problema       Sistema          613
#
#    ID Agente           Severidad        Prioridad  Días Resolución  \
# 0         48  0 - Sin Clasificar  0 - Sin Asignar                0
# 1         17  0 - Sin Clasificar  0 - Sin Asignar                4
#
#    Satisfacción
# 0             5
# 1             5

# %%
excel_2020.to_csv("data/2020.csv")

# %%
csv_2016 = pd.read_csv('data/2016.csv')
csv_2016.head()
# Out:
#            id_ticket       fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453  2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060  2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995  2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006  2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120  2016-06-03       1842.0       31.0       Software
#
#         tipo           severidad        prioridad  días_resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4   Problema          2 - Normal  0 - Sin Asignar              0.0
#
#    satisfacción
# 0           5.0
# 1           5.0
# 2           5.0
# 3           5.0
# 4           5.0

# %%
csv_2017 = pd.read_csv('data/2017.csv')
csv_2017.head()
# Out:
#    Unnamed: 0          ID Ticket       Fecha  ID Empleado  ID Agente  \
# 0           0  GDDEER-8142900901  2017-06-14         1200         29
# 1           1  GDDEST-7342745152  2017-01-10         1855         31
# 2           2  GDLEER-0042906431  2017-06-20          233         34
# 3           3  GDLEER-0042997167  2017-09-19          996         21
# 4           4  GDLEER-0142746832  2017-01-11         1113         48
#
#   Categoría      Tipo           Severidad        Prioridad  Días Resolución  \
# 0  Software  Problema  0 - Sin Clasificar  0 - Sin Asignar                1
# 1   Sistema  Problema  0 - Sin Clasificar  0 - Sin Asignar                3
# 2  Software  Problema          2 - Normal  0 - Sin Asignar                0
# 3  Software  Problema          2 - Normal  0 - Sin Asignar                0
# 4  Software  Problema          2 - Normal  0 - Sin Asignar                1
#
#    Satisfacción
# 0             5
# 1             5
# 2             5
# 3             5
# ...

# %%
csv_2018 = pd.read_csv('data/2018.csv')
csv_2018.head()
# Out:
#    Unnamed: 0          ID Ticket       Fecha  ID Empleado  ID Agente  \
# 0           0  GDDEER-9743106195  2018-01-06          759         21
# 1           1  GDDENR-9043229214  2018-05-09          521          2
# 2           2  GDDENT-9043303547  2018-07-22         1564         45
# 3           3  GDDESR-1243421724  2018-11-17           32         27
# 4           4  GDDESR-8843106588  2018-01-06         1928         45
#
#        Categoría      Tipo           Severidad        Prioridad  \
# 0       Hardware  Problema  0 - Sin Clasificar  0 - Sin Asignar
# 1  Acceso-&Login  Problema  0 - Sin Clasificar  0 - Sin Asignar
# 2  Acceso-&Login  Problema  0 - Sin Clasificar  0 - Sin Asignar
# 3        Sistema  Problema  0 - Sin Clasificar  0 - Sin Asignar
# 4        Sistema  Problema  0 - Sin Clasificar  0 - Sin Asignar
#
#    Días Resolución  Satisfacción
# 0                7             5
# 1                0             5
# 2                0             1
# ...

# %%
csv_2019 = pd.read_csv('data/2019.csv')
csv_2019.head()
# Out:
#    Unnamed: 0          ID Ticket       Fecha  ID Empleado  ID Agente  \
# 0           0  GDDEER-5743562837  2019-04-07         1833         48
# 1           1  GDDEER-6043685286  2019-08-08          528         32
# 2           2  GDDEET-7743705549  2019-08-28          654         45
# 3           3  GDDENR-1043755533  2019-10-17          243         15
# 4           4  GDDESR-9243800417  2019-12-01          601         34
#
#        Categoría      Tipo           Severidad        Prioridad  \
# 0       Hardware  Problema  0 - Sin Clasificar  0 - Sin Asignar
# 1       Hardware  Problema  0 - Sin Clasificar  0 - Sin Asignar
# 2       Hardware  Problema  0 - Sin Clasificar  0 - Sin Asignar
# 3  Acceso99Login  Problema  0 - Sin Clasificar  0 - Sin Asignar
# 4        Sistema  Problema  0 - Sin Clasificar  0 - Sin Asignar
#
#    Días Resolución  Satisfacción
# 0                7             5
# 1               10             5
# 2                7             1
# ...

# %%
csv_2020 = pd.read_csv('data/2020.csv')
csv_2020.head()
# Out:
#    Unnamed: 0          ID Ticket       Fecha      Tipo     Categoría  \
# 0           0  GDDENR-6044135832  2020-10-31  Problema  Acceso/Login
# 1           1  GDDESR-1444031730  2020-07-19  Problema       Sistema
# 2           2  GDDESR-3244128887  2020-10-24  Problema       Sistema
# 3           3  GDDESR-4443972026  2020-05-21  Problema       Sistema
# 4           4  GDDESR-9044014744  2020-07-02  Problema       Sistema
#
#    ID Empleado  ID Agente           Severidad        Prioridad  \
# 0          773         48  0 - Sin Clasificar  0 - Sin Asignar
# 1          613         17  0 - Sin Clasificar  0 - Sin Asignar
# 2         1508          8  0 - Sin Clasificar  0 - Sin Asignar
# 3         1192         20  0 - Sin Clasificar  0 - Sin Asignar
# 4         1224          7  0 - Sin Clasificar  0 - Sin Asignar
#
#    Días Resolución  Satisfacción
# 0                0             5
# 1                4             5
# 2                2             1
# ...

# %%
csv_2017.rename(columns = {col :  col.lower().replace(" ", "_") for col in csv_2017.columns} , inplace = True)
csv_2017 = csv_2017.drop(["unnamed:_0"], axis = 1)
csv_2017.head()
# Out:
#            id_ticket       fecha  id_empleado  id_agente categoría      tipo  \
# 0  GDDEER-8142900901  2017-06-14         1200         29  Software  Problema
# 1  GDDEST-7342745152  2017-01-10         1855         31   Sistema  Problema
# 2  GDLEER-0042906431  2017-06-20          233         34  Software  Problema
# 3  GDLEER-0042997167  2017-09-19          996         21  Software  Problema
# 4  GDLEER-0142746832  2017-01-11         1113         48  Software  Problema
#
#             severidad        prioridad  días_resolución  satisfacción
# 0  0 - Sin Clasificar  0 - Sin Asignar                1             5
# 1  0 - Sin Clasificar  0 - Sin Asignar                3             5
# 2          2 - Normal  0 - Sin Asignar                0             5
# 3          2 - Normal  0 - Sin Asignar                0             5
# 4          2 - Normal  0 - Sin Asignar                1             5

# %%
csv_2018.rename(columns = {col :  col.lower().replace(" ", "_") for col in csv_2018.columns} , inplace = True)
csv_2018 = csv_2018.drop(["unnamed:_0"], axis = 1)
csv_2018.head()
# Out:
#            id_ticket       fecha  id_empleado  id_agente      categoría  \
# 0  GDDEER-9743106195  2018-01-06          759         21       Hardware
# 1  GDDENR-9043229214  2018-05-09          521          2  Acceso-&Login
# 2  GDDENT-9043303547  2018-07-22         1564         45  Acceso-&Login
# 3  GDDESR-1243421724  2018-11-17           32         27        Sistema
# 4  GDDESR-8843106588  2018-01-06         1928         45        Sistema
#
#        tipo           severidad        prioridad  días_resolución  \
# 0  Problema  0 - Sin Clasificar  0 - Sin Asignar                7
# 1  Problema  0 - Sin Clasificar  0 - Sin Asignar                0
# 2  Problema  0 - Sin Clasificar  0 - Sin Asignar                0
# 3  Problema  0 - Sin Clasificar  0 - Sin Asignar                2
# 4  Problema  0 - Sin Clasificar  0 - Sin Asignar                8
#
#    satisfacción
# 0             5
# 1             5
# 2             1
# 3             5
# 4             5

# %%
csv_2019.rename(columns = {col :  col.lower().replace(" ", "_") for col in csv_2019.columns} , inplace = True)
csv_2019 = csv_2019.drop(["unnamed:_0"], axis = 1)
csv_2019.head()
# Out:
#            id_ticket       fecha  id_empleado  id_agente      categoría  \
# 0  GDDEER-5743562837  2019-04-07         1833         48       Hardware
# 1  GDDEER-6043685286  2019-08-08          528         32       Hardware
# 2  GDDEET-7743705549  2019-08-28          654         45       Hardware
# 3  GDDENR-1043755533  2019-10-17          243         15  Acceso99Login
# 4  GDDESR-9243800417  2019-12-01          601         34        Sistema
#
#        tipo           severidad        prioridad  días_resolución  \
# 0  Problema  0 - Sin Clasificar  0 - Sin Asignar                7
# 1  Problema  0 - Sin Clasificar  0 - Sin Asignar               10
# 2  Problema  0 - Sin Clasificar  0 - Sin Asignar                7
# 3  Problema  0 - Sin Clasificar  0 - Sin Asignar                0
# 4  Problema  0 - Sin Clasificar  0 - Sin Asignar                2
#
#    satisfacción
# 0             5
# 1             5
# 2             1
# 3             5
# 4             5

# %%
csv_2020.rename(columns = {col :  col.lower().replace(" ", "_") for col in csv_2020.columns} , inplace = True)
csv_2020 = csv_2020.drop(["unnamed:_0"], axis = 1)
csv_2020.head()
# Out:
#            id_ticket       fecha      tipo     categoría  id_empleado  \
# 0  GDDENR-6044135832  2020-10-31  Problema  Acceso/Login          773
# 1  GDDESR-1444031730  2020-07-19  Problema       Sistema          613
# 2  GDDESR-3244128887  2020-10-24  Problema       Sistema         1508
# 3  GDDESR-4443972026  2020-05-21  Problema       Sistema         1192
# 4  GDDESR-9044014744  2020-07-02  Problema       Sistema         1224
#
#    id_agente           severidad        prioridad  días_resolución  \
# 0         48  0 - Sin Clasificar  0 - Sin Asignar                0
# 1         17  0 - Sin Clasificar  0 - Sin Asignar                4
# 2          8  0 - Sin Clasificar  0 - Sin Asignar                2
# 3         20  0 - Sin Clasificar  0 - Sin Asignar                4
# 4          7  0 - Sin Clasificar  0 - Sin Asignar               10
#
#    satisfacción
# 0             5
# 1             5
# 2             1
# 3             5
# 4             5

# %%
concat1 = pd.concat([csv_2016, csv_2017, csv_2018, csv_2019, csv_2020], axis=0)
concat1
# Out:
#                id_ticket       fecha  id_empleado  id_agente      categoría  \
# 0      GDDENR-5042564453  2016-07-13       1735.0        4.0  Acceso&%Login
# 1      GDDENR-8042508060  2016-05-18       1566.0       10.0  Acceso&%Login
# 2      GDDESR-1342539995  2016-06-18        569.0       29.0        Sistema
# 3      GDDTSR-5942488006  2016-04-28        320.0       40.0        Sistema
# 4      GDLEER-0042524120  2016-06-03       1842.0       31.0       Software
# ...                  ...         ...          ...        ...            ...
# 29083  TWRTSR-8543883120  2020-02-22       1142.0        1.0        Sistema
# 29084  TWRTSR-8744097039  2020-09-23        223.0       40.0        Sistema
# 29085  TWRTSR-9643846768  2020-01-16        256.0        7.0        Sistema
# 29086  TWRTSR-9944138906  2020-11-03       1060.0        9.0        Sistema
# 29087  TWRTST-8643986162  2020-06-04       1876.0       41.0        Sistema
#
# ...

# %%
empleados
# Out:
#      Turno  ID Empleado  Apellido     Nombre ID Puesto  \
# 0        A            6     VILLA      JESUS  50-32200
# 1      NaN           10    MENDEZ    RICARDO  15-24100
# 2      NaN           21   HEREDIA  GUADALUPE  90-14000
# 3      NaN           27     DURAN    DESSENS  15-24100
# 4      NaN           29    LAGUNA   FEDERICO  80-24100
# ...    ...          ...       ...        ...       ...
# 1995   NaN         1903     RAMOS       JOSE  55-23200
# 1996   NaN         1904      RUIZ  GUADALUPE  80-22220
# 1997   NaN         1935    ZEPEDA  FRANCISCO  15-24100
# 1998   NaN         1953    ROBLES  ELIZABETH  15-24100
# 1999   NaN         1993  ENRIQUEZ  HERCULANO  45-11000
#
#                                  Email
# 0            jesus.villa@tractchun.com
# 1         ricardo.mendez@tractchun.com
# 2      guadalupe.heredia@tractchun.com
# 3          dessens.duran@tractchun.com
# 4        federico.laguna@tractchun.com
# ...                                ...
# ...

# %%
puestos.set_index(["ID Puesto"], inplace= True)
puestos

# %%
puestos
# Out:
#            Unnamed: 0                            Puesto  \
# ID Puesto
# 10-23200            0           Ingeniero de Materiales
# 10-24111            1            Operador de Producción
# 10-25120            2               Auxiliar de compras
# 10-25130            3                         Comprador
# 10-32050            4  Supervisor General de Materiales
# ...               ...                               ...
# 90-14110           92                Tecnico de Calidad
# 90-18000           93  Gerente de Ingenieria de Calidad
# 90-23200           94          Ingeniero de Manufactura
# 90-24100           95          Supervisor de Producción
# 90-26100           96                  Clerk de Copiado
#
#                     Departamento     Tipo Puesto
# ID Puesto
# 10-23200              MATERIALES       Operativo
# 10-24111              MATERIALES       Operativo
# 10-25120              MATERIALES  Administrativo
# 10-25130              MATERIALES  Administrativo
# ...

# %%
puestos.drop(["Unnamed: 0"], axis = 1)
puestos
# Out:
#            Unnamed: 0                            Puesto  \
# ID Puesto
# 10-23200            0           Ingeniero de Materiales
# 10-24111            1            Operador de Producción
# 10-25120            2               Auxiliar de compras
# 10-25130            3                         Comprador
# 10-32050            4  Supervisor General de Materiales
# ...               ...                               ...
# 90-14110           92                Tecnico de Calidad
# 90-18000           93  Gerente de Ingenieria de Calidad
# 90-23200           94          Ingeniero de Manufactura
# 90-24100           95          Supervisor de Producción
# 90-26100           96                  Clerk de Copiado
#
#                     Departamento     Tipo Puesto
# ID Puesto
# 10-23200              MATERIALES       Operativo
# 10-24111              MATERIALES       Operativo
# 10-25120              MATERIALES  Administrativo
# 10-25130              MATERIALES  Administrativo
# ...

# %%
puestos_empleados = empleados.join(puestos, on = 'ID Puesto')
puestos_empleados
# Out:
#      Turno  ID Empleado  Apellido     Nombre ID Puesto  \
# 0        A            6     VILLA      JESUS  50-32200
# 1      NaN           10    MENDEZ    RICARDO  15-24100
# 2      NaN           21   HEREDIA  GUADALUPE  90-14000
# 3      NaN           27     DURAN    DESSENS  15-24100
# 4      NaN           29    LAGUNA   FEDERICO  80-24100
# ...    ...          ...       ...        ...       ...
# 1995   NaN         1903     RAMOS       JOSE  55-23200
# 1996   NaN         1904      RUIZ  GUADALUPE  80-22220
# 1997   NaN         1935    ZEPEDA  FRANCISCO  15-24100
# 1998   NaN         1953    ROBLES  ELIZABETH  15-24100
# 1999   NaN         1993  ENRIQUEZ  HERCULANO  45-11000
#
#                                  Email  Unnamed: 0  \
# 0            jesus.villa@tractchun.com          52
# 1         ricardo.mendez@tractchun.com          12
# 2      guadalupe.heredia@tractchun.com          90
# 3          dessens.duran@tractchun.com          12
# ...

# %%
concat1.to_csv("data/union_años.csv")

# %%
puestos_empleados.to_csv("data/puestos_empleados.csv")

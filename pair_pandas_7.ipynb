# %%
import matplotlib.pyplot as plt
import pandas as pd
import re
import datetime
import numpy as np

# %%
df_años = pd.read_csv("data/union_años.csv")
df_años.head()
# Out:
#    Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 0           0  GDDENR-5042564453  2016-07-13       1735.0        4.0
# 1           1  GDDENR-8042508060  2016-05-18       1566.0       10.0
# 2           2  GDDESR-1342539995  2016-06-18        569.0       29.0
# 3           3  GDDTSR-5942488006  2016-04-28        320.0       40.0
# 4           4  GDLEER-0042524120  2016-06-03       1842.0       31.0
#
#        categoría       tipo           severidad        prioridad  \
# 0  Acceso&%Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 1  Acceso&%Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 2        Sistema   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 3        Sistema  Solicitud  0 - Sin Clasificar  0 - Sin Asignar
# 4       Software   Problema          2 - Normal  0 - Sin Asignar
#
#    días_resolución  satisfacción
# 0              0.0           5.0
# 1              0.0           5.0
# 2              3.0           5.0
# ...

# %%
df_puestos = pd.read_csv("data/puestos_empleados.csv")
df_puestos.head()
# Out:
#    Unnamed: 0 Turno  ID Empleado Apellido     Nombre ID Puesto  \
# 0           0     A            6    VILLA      JESUS  50-32200
# 1           1   NaN           10   MENDEZ    RICARDO  15-24100
# 2           2   NaN           21  HEREDIA  GUADALUPE  90-14000
# 3           3   NaN           27    DURAN    DESSENS  15-24100
# 4           4   NaN           29   LAGUNA   FEDERICO  80-24100
#
#                              Email  Unnamed: 0.1  \
# 0        jesus.villa@tractchun.com            52
# 1     ricardo.mendez@tractchun.com            12
# 2  guadalupe.heredia@tractchun.com            90
# 3      dessens.duran@tractchun.com            12
# 4    federico.laguna@tractchun.com            87
#
#                                 Puesto           Departamento     Tipo Puesto
# 0              Comprador de Materiales  CONTROL DE PRODUCCION  Administrativo
# 1             Supervisor de Producción             PRODUCCION   Mandos Medios
# ...

# %%
 patron = {"mes1": "Enero", "mes2":"Febrero", "mes3":"Marzo","mes4":"Abril","mes5":"Mayo", "mes6":"Junio", "mes7": "Julio", "mes8": "Agosto", "mes9":"septiembre", "mes10":"Octubre", "mes11":"Noviembre","mes12":"Diciembre"}

# %%
enero = "\d{4}-01-\d{2}"
febrero = "\d{4}-02-\d{2}"
marzo = "\d{4}-03-\d{2}"
abril = "\d{4}-04-\d{2}"
mayo = "\d{4}-05-\d{2}"
junio = "\d{4}-06-\d{2}"
julio = "\d{4}-07-\d{2}"
agosto = "\d{4}-08-\d{2}"
septiembre = "\d{4}-09-\d{2}"
octubre = "\d{4}-10-\d{2}"
noviembre = "\d{4}-11-\d{2}"
diciembre = "\d{4}-12-\d{2}"

# %%
mes1= "Enero"
mes2="Febrero"
mes3="Marzo"
mes4="Abril"
mes5="Mayo"
mes6="Junio"
mes7= "Julio"
mes8= "Agosto"
mes9="septiembre"
mes10="Octubre"
mes11="Noviembre"
mes12="Diciembre"

# %%
def sacar_mes(fecha):
    try:
        
        return fecha.split("-")[1]
    except:
        return np.nan

# %%
df_años["meses"] = (df_años["fecha"].apply(sacar_mes))

# %%
df_años
# Out:
#        Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 0               0  GDDENR-5042564453  2016-07-13       1735.0        4.0
# 1               1  GDDENR-8042508060  2016-05-18       1566.0       10.0
# 2               2  GDDESR-1342539995  2016-06-18        569.0       29.0
# 3               3  GDDTSR-5942488006  2016-04-28        320.0       40.0
# 4               4  GDLEER-0042524120  2016-06-03       1842.0       31.0
# ...           ...                ...         ...          ...        ...
# 97493       29083  TWRTSR-8543883120  2020-02-22       1142.0        1.0
# 97494       29084  TWRTSR-8744097039  2020-09-23        223.0       40.0
# 97495       29085  TWRTSR-9643846768  2020-01-16        256.0        7.0
# 97496       29086  TWRTSR-9944138906  2020-11-03       1060.0        9.0
# 97497       29087  TWRTST-8643986162  2020-06-04       1876.0       41.0
#
#            categoría       tipo           severidad        prioridad  \
# ...

# %%
"""
def cambio_meses(meses):
  
  for i in meses:
  
    if i == "01" :
      df_años["meses"].replace(to_replace = "01", value ="Enero", inplace = True)
      
    elif i == "02":
      df_años["meses"].replace(to_replace = "02", value ="Febrero", inplace = True)
      
    elif i == "07":
      df_años["meses"].replace(to_replace = "07", value ="Julio", inplace = True)
    
    else:
        pass
        """

# %%
def cambio_meses(meses):
  

  
    try:
      return df_años["meses"].replace({"01": "Enero", "02":"Febrero", "03":"Marzo","04":"Abril","05":"Mayo", "06":"Junio", "07": "Julio", "08": "Agosto", "09":"septiembre", "10":"Octubre", "11":"Noviembre","12":"Diciembre"}, inplace = True)
      
    except:
        return np.nan

# %%
# df_años["meses"].replace(to_replace = "02", value ="Febrero", inplace = True)

# %%
# df_años["meses"].replace({"01": "Enero", "02":"Febrero", "03":"Marzo","04":"Abril","05":"Mayo", "06":"Junio", "07": "Julio", "08": "Agosto", "09":"septiembre", "10":"Octubre", "11":"Noviembre","12":"Diciembre"}, inplace = True)

# %%
df_años["mes"] = (df_años["meses"].apply(cambio_meses))

# %%
df_años
# Out:
#        Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 0               0  GDDENR-5042564453  2016-07-13       1735.0        4.0
# 1               1  GDDENR-8042508060  2016-05-18       1566.0       10.0
# 2               2  GDDESR-1342539995  2016-06-18        569.0       29.0
# 3               3  GDDTSR-5942488006  2016-04-28        320.0       40.0
# 4               4  GDLEER-0042524120  2016-06-03       1842.0       31.0
# ...           ...                ...         ...          ...        ...
# 97493       29083  TWRTSR-8543883120  2020-02-22       1142.0        1.0
# 97494       29084  TWRTSR-8744097039  2020-09-23        223.0       40.0
# 97495       29085  TWRTSR-9643846768  2020-01-16        256.0        7.0
# 97496       29086  TWRTSR-9944138906  2020-11-03       1060.0        9.0
# 97497       29087  TWRTST-8643986162  2020-06-04       1876.0       41.0
#
#            categoría       tipo           severidad        prioridad  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1094/2352515093.py in <module>
# ----> 1 df_años["meses"] = (df_años["meses"].apply(cambio_meses))
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
# ...

# %%
type(df_años["meses"])
# Out:
# pandas.core.series.Series

# %%
df_años.dtypes
# Out:
# Unnamed: 0           int64
# id_ticket           object
# fecha               object
# id_empleado        float64
# id_agente          float64
# categoría           object
# tipo                object
# severidad           object
# prioridad           object
# días_resolución    float64
# satisfacción       float64
# meses               object
# dtype: object

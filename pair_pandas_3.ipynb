# %%
import pandas as pd
import re

# %%
excel_2016 = pd.read_excel('data/2016.xlsx')
excel_2016.head()
# Out:
#            ID Ticket      Fecha  ID Empleado  ID Agente      Categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
#
#         Tipo           Severidad        Prioridad  Días Resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4   Problema          2 - Normal  0 - Sin Asignar              0.0
#
#    Satisfacción               Web  Índice
# 0           5.0  www.tractchun.es      1.0
# 1           5.0  www.tractchun.es      1.0
# ...

# %%
puestos = pd.read_excel('data/Puestos.xlsx')
puestos.head()
# Out:
#   ID Puesto                            Puesto Departamento     Tipo Puesto
# 0  10-23200           Ingeniero de Materiales   MATERIALES       Operativo
# 1  10-24111            Operador de Producción   MATERIALES       Operativo
# 2  10-25120               Auxiliar de compras   MATERIALES  Administrativo
# 3  10-25130                         Comprador   MATERIALES  Administrativo
# 4  10-32050  Supervisor General de Materiales   MATERIALES   Mandos Medios

# %%
agentes = pd.read_csv('data/Agentes.csv')
agentes.head()
# Out:
#    ID Agente               Nombre                              email  \
# 0          1          Mata Lucero          lucero.mata@tractchun.com
# 1          2         JesusGrajeda        jesus.grajeda@tractchun.com
# 2          3          Elena Velez          elena.velez@tractchun.com
# 3          4      Barraza Alberto      alberto.barraza@tractchun.com
# 4          5  Willyberto Gonzales  willyberto.gonzales@tractchun.com
#
#   Fecha de Nacimiento
# 0           1989/4/28
# 1            1979/1/1
# 2            1993/6/6
# 3          1978/10/20
# 4           1973/5/11

# %%
empleados = pd.read_csv('data/Empleados.csv')
empleados.head()
# Out:
#   Turno  ID Empleado Apellido     Nombre ID Puesto  \
# 0     A            6    VILLA      JESUS  50-32200
# 1   NaN           10   MENDEZ    RICARDO  15-24100
# 2   NaN           21  HEREDIA  GUADALUPE  90-14000
# 3   NaN           27    DURAN    DESSENS  15-24100
# 4   NaN           29   LAGUNA   FEDERICO  80-24100
#
#                              Email
# 0        jesus.villa@tractchun.com
# 1     ricardo.mendez@tractchun.com
# 2  guadalupe.heredia@tractchun.com
# 3      dessens.duran@tractchun.com
# 4    federico.laguna@tractchun.com

# %%
def analisis_archivo (archivo):
    print(archivo.shape)
    print(archivo.head())
    print(archivo.describe().T)
    print(archivo.columns)
    print(archivo.sample(2))
    print(archivo.tail())
    print(archivo.info())
    return archivo

# %%
analisis_archivo(agentes)
# Out:
# (50, 4)
#    ID Agente               Nombre                              email  \
# 0          1          Mata Lucero          lucero.mata@tractchun.com
# 1          2         JesusGrajeda        jesus.grajeda@tractchun.com
# 2          3          Elena Velez          elena.velez@tractchun.com
# 3          4      Barraza Alberto      alberto.barraza@tractchun.com
# 4          5  Willyberto Gonzales  willyberto.gonzales@tractchun.com
#
#   Fecha de Nacimiento
# 0           1989/4/28
# 1            1979/1/1
# 2            1993/6/6
# 3          1978/10/20
# 4           1973/5/11
#            count  mean       std  min    25%   50%    75%   max
# ID Agente   50.0  25.5  14.57738  1.0  13.25  25.5  37.75  50.0
# Index(['ID Agente', 'Nombre', 'email', 'Fecha de Nacimiento'], dtype='object')
#     ID Agente   Nombre                          email Fecha de Nacimiento
# 21         22   Lorena      lorena.leon@tractchun.com           1996/7/16
# ...

# %%
analisis_archivo(empleados)
# Out:
# (2000, 6)
#   Turno  ID Empleado Apellido     Nombre ID Puesto  \
# 0     A            6    VILLA      JESUS  50-32200
# 1   NaN           10   MENDEZ    RICARDO  15-24100
# 2   NaN           21  HEREDIA  GUADALUPE  90-14000
# 3   NaN           27    DURAN    DESSENS  15-24100
# 4   NaN           29   LAGUNA   FEDERICO  80-24100
#
#                              Email
# 0        jesus.villa@tractchun.com
# 1     ricardo.mendez@tractchun.com
# 2  guadalupe.heredia@tractchun.com
# 3      dessens.duran@tractchun.com
# 4    federico.laguna@tractchun.com
#               count    mean         std  min     25%     50%      75%     max
# ID Empleado  2000.0  1000.5  577.494589  1.0  500.75  1000.5  1500.25  2000.0
# Index(['Turno', 'ID Empleado', 'Apellido', 'Nombre', 'ID Puesto', 'Email'], dtype='object')
#      Turno  ID Empleado   Apellido   Nombre ID Puesto  \
# 1117   NaN          260     ROMERO  ALBERTO  70-21110
# 110    NaN          661  MOROYOQUI   RIVERA  55-23200
#
# ...

# %%
analisis_archivo(puestos)
# Out:
# (97, 4)
#   ID Puesto                            Puesto Departamento     Tipo Puesto
# 0  10-23200           Ingeniero de Materiales   MATERIALES       Operativo
# 1  10-24111            Operador de Producción   MATERIALES       Operativo
# 2  10-25120               Auxiliar de compras   MATERIALES  Administrativo
# 3  10-25130                         Comprador   MATERIALES  Administrativo
# 4  10-32050  Supervisor General de Materiales   MATERIALES   Mandos Medios
#              count unique                       top freq
# ID Puesto       97     97                  10-23200    1
# Puesto          97     78  Auxiliar de Departamento    3
# Departamento    97     11             MANTENIMIENTO   17
# Tipo Puesto     97      4             Mandos Medios   38
# Index(['ID Puesto', 'Puesto', 'Departamento', 'Tipo Puesto'], dtype='object')
#    ID Puesto                                  Puesto           Departamento  \
# ...

# %%
analisis_archivo(excel_2016)
# Out:
# (13051, 12)
#            ID Ticket      Fecha  ID Empleado  ID Agente      Categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
#
#         Tipo           Severidad        Prioridad  Días Resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4   Problema          2 - Normal  0 - Sin Asignar              0.0
#
#    Satisfacción               Web  Índice
# 0           5.0  www.tractchun.es      1.0
# ...

# %%
# Pasamos las columnas a minúsculas:
excel_2016.rename(columns = {col :  col.lower().replace(" ", "_") for col in excel_2016.columns} , inplace = True)

# %%
excel_2016
# Out:
#                id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0      GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1      GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2      GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3      GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4      GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
# ...                  ...        ...          ...        ...            ...
# 13046  TWRTSR-6442574526 2016-07-23        962.0       25.0        Sistema
# 13047  TWRTSR-7142570866 2016-07-19        126.0       38.0        Sistema
# 13048  TWRTSR-7742498308 2016-05-08        510.0        3.0        Sistema
# 13049  TWRTSR-8642558628 2016-07-07       1942.0       26.0        Sistema
# 13050  TWRTSR-8742628897 2016-09-15        919.0        8.0        Sistema
#
# ...

# %%
#excel_2016.drop( [10,12] , axis =1)

df_eliminar2 = excel_2016.drop(["web"], axis = 1)
df_eliminar2
# Out:
#                id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0      GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1      GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2      GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3      GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4      GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
# ...                  ...        ...          ...        ...            ...
# 13046  TWRTSR-6442574526 2016-07-23        962.0       25.0        Sistema
# 13047  TWRTSR-7142570866 2016-07-19        126.0       38.0        Sistema
# 13048  TWRTSR-7742498308 2016-05-08        510.0        3.0        Sistema
# 13049  TWRTSR-8642558628 2016-07-07       1942.0       26.0        Sistema
# 13050  TWRTSR-8742628897 2016-09-15        919.0        8.0        Sistema
#
# ...

# %%
excel_2016.set_index(["id ticket"], inplace= True)

# %%
excel_2016
# Out:
#                        fecha  id empleado  id agente      categoría  \
# id ticket
# GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
# ...                      ...          ...        ...            ...
# TWRTSR-6442574526 2016-07-23        962.0       25.0        Sistema
# TWRTSR-7142570866 2016-07-19        126.0       38.0        Sistema
# TWRTSR-7742498308 2016-05-08        510.0        3.0        Sistema
# TWRTSR-8642558628 2016-07-07       1942.0       26.0        Sistema
# TWRTSR-8742628897 2016-09-15        919.0        8.0        Sistema
#
#                         tipo           severidad        prioridad  \
# id ticket
# ...

# %%
# El ejercicio para eliminar la comunma índice está correcta pero nos da fallos al llamar a dicha columna:

df_eliminar2 = excel_2016.drop(["índice"], axis = 1)
df_eliminar2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_715/2058504182.py in <module>
#       1 # El ejercicio para eliminar la comunma índice está correcta pero nos da fallos al llamar a dicha columna:
#       2
# ----> 3 df_eliminar2 = excel_2016.drop(["índice"], axis = 1)
#       4 df_eliminar2
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
# ...

# %%
excel_2016.to_csv("data/2016.csv")

# %%
puestos.to_csv("data/puestos.csv")
